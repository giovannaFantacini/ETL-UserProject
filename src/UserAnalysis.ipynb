# %% [markdown]
# # Extract

# %%
import requests
import pandas as pd
import json

urlreq = 'https://64e2780eab003735881904fb.mockapi.io/apiInfo/userInfo'

def getUsers():
    response = requests.get(urlreq)
    return response.json() if response.status_code == 200 else None

users = getUsers()
print(json.dumps(users, indent=2))
# Out:
# [
#   {
#     "createdAt": "2023-08-20T04:49:02.368Z",
#     "name": "Miss Stewart Nicolas",
#     "job": "Interactions",
#     "gender": "Gender fluid",
#     "companyName": "Hayes and Sons",
#     "product": "Luxurious Concrete Gloves",
#     "marketing": {},
#     "id": "1"
#   },
#   {
#     "createdAt": "2023-08-19T23:12:57.187Z",
#     "name": "Ken Upton",
#     "job": "Accountability",
#     "gender": "Male to female trans woman",
#     "companyName": "Koelpin - Luettgen",
#     "product": "Fantastic Granite Bike",
#     "marketing": {},
#     "id": "2"
#   },
#   {
#     "createdAt": "2023-08-20T07:32:35.431Z",
#     "name": "Earnest Nicolas",
#     "job": "Quality",
#     "gender": "Female to male",
#     "companyName": "Hirthe, Bernier and Cartwright",
#     "product": "Ergonomic Fresh Chicken",
#     "marketing": {},
#     "id": "3"
#   },
#   {
#     "createdAt": "2023-08-20T11:35:32.750Z",
#     "name": "Ms. Marie Harvey",
#     "job": "Mobility",
#     "gender": "Trans woman",
#     "companyName": "Kuvalis, Auer and D'Amore",
#     "product": "Sleek Concrete Salad",
#     "marketing": {},
#     "id": "4"
#   },
#   {
#     "createdAt": "2023-08-19T21:38:33.842Z",
#     "name": "Chris Gorczany",
#     "job": "Solutions",
#     "gender": "Demi-woman",
#     "companyName": "Stokes and Sons",
#     "product": "Unbranded Concrete Car",
#     "marketing": {},
#     "id": "5"
#   },
#   {
#     "createdAt": "2023-08-20T18:37:20.905Z",
#     "name": "Ryan Vandervort II",
#     "job": "Integration",
#     "gender": "Cis",
#     "companyName": "Bahringer - Kuhlman",
#     "product": "Handcrafted Soft Car",
#     "marketing": {},
#     "id": "6"
#   },
#   {
#     "createdAt": "2023-08-20T01:15:01.862Z",
#     "name": "Ms. Connie Gleichner",
#     "job": "Assurance",
#     "gender": "Male to female transsexual woman",
#     "companyName": "Veum and Sons",
#     "product": "Handmade Rubber Cheese",
#     "marketing": {},
#     "id": "7"
#   },
#   {
#     "createdAt": "2023-08-20T03:26:38.256Z",
#     "name": "Jackie Hodkiewicz",
#     "job": "Configuration",
#     "gender": "Cisgender man",
#     "companyName": "Koelpin, Littel and Schuster",
#     "product": "Luxurious Fresh Gloves",
#     "marketing": {},
#     "id": "8"
#   },
#   {
#     "createdAt": "2023-08-20T09:37:10.620Z",
#     "name": "Mrs. Eileen Homenick",
#     "job": "Security",
#     "gender": "Cis woman",
#     "companyName": "VonRueden LLC",
#     "product": "Oriental Concrete Towels",
#     "marketing": {},
#     "id": "9"
#   },
#   {
#     "createdAt": "2023-08-20T17:45:54.625Z",
#     "name": "Silvia Dicki",
#     "job": "Branding",
#     "gender": "Two-spirit person",
#     "companyName": "White, Huel and Larkin",
#     "product": "Oriental Metal Car",
#     "marketing": {},
#     "id": "10"
#   },
#   {
#     "createdAt": "2023-08-20T06:44:57.704Z",
#     "name": "Bonnie Will",
#     "job": "Applications",
#     "gender": "Transexual",
#     "companyName": "Nitzsche, Bins and Howe",
#     "product": "Handcrafted Cotton Bacon",
#     "marketing": {},
#     "id": "11"
#   },
#   {
#     "createdAt": "2023-08-20T05:39:06.479Z",
#     "name": "Wilfred Jenkins",
#     "job": "Group",
#     "gender": "Female to male trans man",
#     "companyName": "Marvin - Simonis",
#     "product": "Licensed Metal Towels",
#     "marketing": {},
#     "id": "12"
#   },
#   {
#     "createdAt": "2023-08-20T14:53:48.747Z",
#     "name": "Miss Alejandro Douglas",
#     "job": "Directives",
#     "gender": "Cis man",
#     "companyName": "Hartmann Group",
#     "product": "Tasty Metal Chair",
#     "marketing": {},
#     "id": "13"
#   },
#   {
#     "createdAt": "2023-08-20T10:31:45.365Z",
#     "name": "Kimberly Schowalter",
#     "job": "Identity",
#     "gender": "Trigender",
#     "companyName": "Nitzsche and Sons",
#     "product": "Electronic Concrete Table",
#     "marketing": {},
#     "id": "14"
#   },
#   {
#     "createdAt": "2023-08-20T02:38:06.622Z",
#     "name": "Carole Cartwright",
#     "job": "Optimization",
#     "gender": "Neutrois",
#     "companyName": "Franey Inc",
#     "product": "Elegant Bronze Ball",
#     "marketing": {},
#     "id": "15"
#   },
#   {
#     "createdAt": "2023-08-20T18:24:22.052Z",
#     "name": "Merle Kling I",
#     "job": "Intranet",
#     "gender": "Two-spirit person",
#     "companyName": "Wisoky - Ryan",
#     "product": "Unbranded Granite Chicken",
#     "marketing": {},
#     "id": "16"
#   },
#   {
#     "createdAt": "2023-08-20T14:48:13.640Z",
#     "name": "Allison Ryan",
#     "job": "Group",
#     "gender": "Female to male trans man",
#     "companyName": "Stroman, Schmeler and Collier",
#     "product": "Refined Granite Fish",
#     "marketing": {},
#     "id": "17"
#   },
#   {
#     "createdAt": "2023-08-20T01:37:17.897Z",
#     "name": "Mandy O'Conner",
#     "job": "Solutions",
#     "gender": "Neither",
#     "companyName": "Kshlerin - Schmitt",
#     "product": "Licensed Frozen Shirt",
#     "marketing": {},
#     "id": "18"
#   },
#   {
#     "createdAt": "2023-08-20T05:07:26.755Z",
#     "name": "Angel Kertzmann",
#     "job": "Paradigm",
#     "gender": "Gender nonconforming",
#     "companyName": "Ferry, Funk and Heaney",
#     "product": "Intelligent Concrete Pants",
#     "marketing": {},
#     "id": "19"
#   },
#   {
#     "createdAt": "2023-08-20T00:38:15.435Z",
#     "name": "Elisa Moen",
#     "job": "Optimization",
#     "gender": "Transexual man",
#     "companyName": "Lehner - Sporer",
#     "product": "Small Fresh Gloves",
#     "marketing": {},
#     "id": "20"
#   },
#   {
#     "createdAt": "2023-08-19T21:52:04.634Z",
#     "name": "Joanna Dicki",
#     "job": "Quality",
#     "gender": "Male to female trans woman",
#     "companyName": "McDermott Inc",
#     "product": "Tasty Plastic Bike",
#     "marketing": {},
#     "id": "21"
#   },
#   {
#     "createdAt": "2023-08-20T03:38:19.551Z",
#     "name": "Darnell Stokes II",
#     "job": "Tactics",
#     "gender": "Other",
#     "companyName": "Kling Group",
#     "product": "Unbranded Wooden Hat",
#     "marketing": {},
#     "id": "22"
#   },
#   {
#     "createdAt": "2023-08-20T05:37:48.522Z",
#     "name": "Bethany Barton",
#     "job": "Marketing",
#     "gender": "Demigender",
#     "companyName": "Hamill Group",
#     "product": "Luxurious Cotton Pizza",
#     "marketing": {},
#     "id": "23"
#   },
#   {
#     "createdAt": "2023-08-20T13:10:09.771Z",
#     "name": "Seth Spinka",
#     "job": "Brand",
#     "gender": "Non-binary",
#     "companyName": "Renner - Harvey",
#     "product": "Refined Soft Pants",
#     "marketing": {},
#     "id": "24"
#   },
#   {
#     "createdAt": "2023-08-19T21:44:06.184Z",
#     "name": "Josephine King",
#     "job": "Metrics",
#     "gender": "Trans",
#     "companyName": "Huels, Bernier and Weber",
#     "product": "Refined Metal Towels",
#     "marketing": {},
#     "id": "25"
#   },
#   {
#     "createdAt": "2023-08-20T05:59:31.963Z",
#     "name": "Guadalupe Becker",
#     "job": "Paradigm",
#     "gender": "Androgyne",
#     "companyName": "Marvin, Koepp and Kris",
#     "product": "Practical Bronze Pants",
#     "marketing": {},
#     "id": "26"
#   },
#   {
#     "createdAt": "2023-08-20T01:33:51.581Z",
#     "name": "Micheal Gorczany",
#     "job": "Metrics",
#     "gender": "Cis woman",
#     "companyName": "Smitham, Wilderman and Bednar",
#     "product": "Practical Metal Tuna",
#     "marketing": {},
#     "id": "27"
#   },
#   {
#     "createdAt": "2023-08-20T03:36:14.173Z",
#     "name": "Roderick Predovic",
#     "job": "Security",
#     "gender": "Demi-girl",
#     "companyName": "Vandervort, Reinger and Thompson",
#     "product": "Incredible Metal Chips",
#     "marketing": {},
#     "id": "28"
#   },
#   {
#     "createdAt": "2023-08-20T19:35:00.113Z",
#     "name": "Miss Joey Mosciski",
#     "job": "Functionality",
#     "gender": "Woman",
#     "companyName": "Quitzon - Wilderman",
#     "product": "Oriental Cotton Chips",
#     "marketing": {},
#     "id": "29"
#   },
#   {
#     "createdAt": "2023-08-20T21:07:25.087Z",
#     "name": "Sonia Swift",
#     "job": "Security",
#     "gender": "Intersex",
#     "companyName": "Gibson and Sons",
#     "product": "Sleek Fresh Gloves",
#     "marketing": {},
#     "id": "30"
#   },
#   {
#     "createdAt": "2023-08-20T18:27:40.729Z",
#     "name": "Florence Hessel",
#     "job": "Division",
#     "gender": "Transmasculine",
#     "companyName": "Bartell - Stokes",
#     "product": "Incredible Frozen Tuna",
#     "marketing": {},
#     "id": "31"
#   },
#   {
#     "createdAt": "2023-08-20T19:00:20.885Z",
#     "name": "Gertrude Ratke",
#     "job": "Tactics",
#     "gender": "Two-spirit",
#     "companyName": "Gibson, Stark and Becker",
#     "product": "Handmade Granite Chips",
#     "marketing": {},
#     "id": "32"
#   },
#   {
#     "createdAt": "2023-08-20T00:24:36.485Z",
#     "name": "Bill Carter",
#     "job": "Usability",
#     "gender": "Intersex",
#     "companyName": "Abernathy - Nolan",
#     "product": "Ergonomic Wooden Sausages",
#     "marketing": {},
#     "id": "33"
#   },
#   {
#     "createdAt": "2023-08-20T10:45:20.373Z",
#     "name": "Meredith Baumbach",
#     "job": "Implementation",
#     "gender": "Female to male transgender man",
#     "companyName": "Gerlach Group",
#     "product": "Incredible Granite Computer",
#     "marketing": {},
#     "id": "34"
#   },
#   {
#     "createdAt": "2023-08-19T23:52:13.406Z",
#     "name": "Pauline Ferry",
#     "job": "Implementation",
#     "gender": "Female to male transgender man",
#     "companyName": "Lebsack - Wilkinson",
#     "product": "Incredible Frozen Gloves",
#     "marketing": {},
#     "id": "35"
#   },
#   {
#     "createdAt": "2023-08-20T04:09:21.986Z",
#     "name": "Leona Daugherty",
#     "job": "Usability",
#     "gender": "Genderqueer",
#     "companyName": "West, Kovacek and Johnson",
#     "product": "Fantastic Wooden Ball",
#     "marketing": {},
#     "id": "36"
#   },
#   {
#     "createdAt": "2023-08-20T05:09:07.392Z",
#     "name": "Juan DuBuque",
#     "job": "Mobility",
#     "gender": "Cis",
#     "companyName": "Rau - Stroman",
#     "product": "Handmade Plastic Fish",
#     "marketing": {},
#     "id": "37"
#   },
#   {
#     "createdAt": "2023-08-20T21:00:57.392Z",
#     "name": "Opal Huel Sr.",
#     "job": "Division",
#     "gender": "Genderflux",
#     "companyName": "Rodriguez - Pagac",
#     "product": "Ergonomic Granite Computer",
#     "marketing": {},
#     "id": "38"
#   },
#   {
#     "createdAt": "2023-08-20T03:33:49.940Z",
#     "name": "Annette Mraz",
#     "job": "Integration",
#     "gender": "F2M",
#     "companyName": "Heller Inc",
#     "product": "Practical Rubber Soap",
#     "marketing": {},
#     "id": "39"
#   },
#   {
#     "createdAt": "2023-08-20T16:45:37.715Z",
#     "name": "Mandy Harris",
#     "job": "Marketing",
#     "gender": "Trans",
#     "companyName": "Wolff, Rolfson and Considine",
#     "product": "Bespoke Steel Ball",
#     "marketing": {},
#     "id": "40"
#   },
#   {
#     "createdAt": "2023-08-20T15:13:39.055Z",
#     "name": "Hazel Koch",
#     "job": "Program",
#     "gender": "Other",
#     "companyName": "Stehr - Okuneva",
#     "product": "Gorgeous Steel Chicken",
#     "marketing": {},
#     "id": "41"
#   },
#   {
#     "createdAt": "2023-08-20T13:09:09.129Z",
#     "name": "Maryann Dicki DDS",
#     "job": "Configuration",
#     "gender": "Gender neutral",
#     "companyName": "Cassin, Leuschke and Wiegand",
#     "product": "Rustic Steel Table",
#     "marketing": {},
#     "id": "42"
#   },
#   {
#     "createdAt": "2023-08-20T14:02:01.525Z",
#     "name": "Elsie Cummerata",
#     "job": "Group",
#     "gender": "Trans person",
#     "companyName": "Tillman Group",
#     "product": "Unbranded Metal Table",
#     "marketing": {},
#     "id": "43"
#   },
#   {
#     "createdAt": "2023-08-20T07:56:53.408Z",
#     "name": "Lisa Goyette",
#     "job": "Assurance",
#     "gender": "Trans male",
#     "companyName": "Beier - Wiza",
#     "product": "Practical Metal Tuna",
#     "marketing": {},
#     "id": "44"
#   },
#   {
#     "createdAt": "2023-08-20T20:28:54.167Z",
#     "name": "Joanna Kohler",
#     "job": "Usability",
#     "gender": "Male to female transsexual woman",
#     "companyName": "Bruen - Gorczany",
#     "product": "Awesome Plastic Mouse",
#     "marketing": {},
#     "id": "45"
#   },
#   {
#     "createdAt": "2023-08-20T06:42:34.592Z",
#     "name": "Steve Stehr",
#     "job": "Security",
#     "gender": "Demi-man",
#     "companyName": "Quitzon Inc",
#     "product": "Refined Frozen Mouse",
#     "marketing": {},
#     "id": "46"
#   },
#   {
#     "createdAt": "2023-08-20T09:27:24.376Z",
#     "name": "Deborah Toy",
#     "job": "Mobility",
#     "gender": "Trans female",
#     "companyName": "Herman Inc",
#     "product": "Intelligent Cotton Mouse",
#     "marketing": {},
#     "id": "47"
#   },
#   {
#     "createdAt": "2023-08-20T17:27:29.027Z",
#     "name": "Connie Hessel",
#     "job": "Accountability",
#     "gender": "MTF",
#     "companyName": "Lebsack Group",
#     "product": "Ergonomic Wooden Tuna",
#     "marketing": {},
#     "id": "48"
#   },
#   {
#     "createdAt": "2023-08-20T08:20:24.030Z",
#     "name": "Santos Yundt",
#     "job": "Program",
#     "gender": "Intersex person",
#     "companyName": "Kuhlman, Will and Anderson",
#     "product": "Small Frozen Fish",
#     "marketing": {},
#     "id": "49"
#   },
#   {
#     "createdAt": "2023-08-20T14:12:34.602Z",
#     "name": "Shane O'Reilly",
#     "job": "Program",
#     "gender": "Androgyne",
#     "companyName": "Wolf - O'Keefe",
#     "product": "Licensed Concrete Bike",
#     "marketing": {},
#     "id": "50"
#   }
# ]

# %% [markdown]
# # Transform

# %%
import openai
import time

openai_api_key = ''
openai.api_key = openai_api_key

def generate_ai_message(user):
  completion = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
      {
          "role": "system",
          "content": "Você é um especialista em markting."
      },
      {
          "role": "user",
          "content": f"Crie uma mensagem de marketing para {user['name']} de acordo com o seu trabalho {user['job']} e o produto que ele está buscando {user['product']} (máximo de 100 caracteres)"
      }
    ]
  )
  return completion.choices[0].message.content.strip('\"')

for user in users:
  message = generate_ai_message(user)
  print(message)
  user['marketing'].update({'message': message})
  time.sleep(20)
# Out:
# Eleve sua experiência no mundo da construção com as Luxurious Concrete Gloves de Miss Stewart Nicolas. Seu conforto e proteção garantidos! #LuxuriousConcreteGloves
# Eleve sua performance com a Fantastic Granite Bike de Ken Upton. Responsabilidade e qualidade em cada pedalada!
# Qualidade e conforto para seu paladar: Ergonomic Fresh Chicken é a melhor escolha para uma refeição deliciosa!
# Desperte seus sentidos com a elegância do Sleek Concrete Salad - Sua solução perfeita para uma experiência gastronômica inovadora! #SleekConcreteSalad #GourmetAbsoluto
# Potencialize sua marca com o Unbranded Concrete Car da Solutions. Mercado sólido, visibilidade incomparável. Eleve seus negócios!
# Integre estilo e conforto com o Handcrafted Soft Car, o melhor veículo para quem valoriza qualidade e detalhes únicos! #RyanVandervortII
# Garanta segurança e qualidade com Assurance! Experimente nosso delicioso queijo de borracha artesanal hoje mesmo! 🧀🔒
# Experimente a perfeição em proteção e estilo com os Luxurious Fresh Gloves de Jackie Hodkiewicz. Sua configuração personalizada é imbatível. #ElegânciaFuncional
# Proteja seu espaço com as toalhas concretas orientais: segurança e estilo em cada aplicação!
# Oriental Metal Car: Fortaleça sua marca com estilo e qualidade excepcionais. Conte com Silvia Dicki para elevar o branding da sua empresa!

# %%
def update_user(user):
  response = requests.put(f"{urlreq}/{user['id']}", json=user)
  return True if response.status_code == 200 else False

for user in users:
  success = update_user(user)
  print(f"User {user['name']} updated? {success}!")
# Out:
# User Miss Stewart Nicolas updated? True!
# User Ken Upton updated? True!
# User Earnest Nicolas updated? True!
# User Ms. Marie Harvey updated? True!
# User Chris Gorczany updated? True!
# User Ryan Vandervort II updated? True!
# User Ms. Connie Gleichner updated? True!
# User Jackie Hodkiewicz updated? True!
# User Mrs. Eileen Homenick updated? True!
# User Silvia Dicki updated? True!
# User Bonnie Will updated? True!
# User Wilfred Jenkins updated? True!
# User Miss Alejandro Douglas updated? True!
# User Kimberly Schowalter updated? True!
# User Carole Cartwright updated? True!
# User Merle Kling I updated? True!
# User Allison Ryan updated? True!
# User Mandy O'Conner updated? True!
# User Angel Kertzmann updated? True!
# User Elisa Moen updated? True!
# User Joanna Dicki updated? True!
# User Darnell Stokes II updated? True!
# User Bethany Barton updated? True!
# User Seth Spinka updated? True!
# User Josephine King updated? True!
# User Guadalupe Becker updated? True!
# User Micheal Gorczany updated? True!
# User Roderick Predovic updated? True!
# User Miss Joey Mosciski updated? True!
# User Sonia Swift updated? True!
# User Florence Hessel updated? True!
# User Gertrude Ratke updated? True!
# User Bill Carter updated? True!
# User Meredith Baumbach updated? True!
# User Pauline Ferry updated? True!
# User Leona Daugherty updated? True!
# User Juan DuBuque updated? False!
# User Opal Huel Sr. updated? True!
# User Annette Mraz updated? False!
# User Mandy Harris updated? True!
# User Hazel Koch updated? False!
# User Maryann Dicki DDS updated? False!
# User Elsie Cummerata updated? False!
# User Lisa Goyette updated? True!
# User Joanna Kohler updated? False!
# User Steve Stehr updated? False!
# User Deborah Toy updated? True!
# User Connie Hessel updated? False!
# User Santos Yundt updated? False!
# User Shane O'Reilly updated? False!
